# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # Export Configuration
#
# Configure which model formats to export. Multiple formats can be enabled simultaneously.

# %%
# ============================================
# EXPORT CONFIGURATION
# ============================================

# Quantization Options
EXPORT_INT8_FULL = False
EXPORT_FP16 = False
EXPORT_DYNAMIC = False
EXPORT_INT8_PRUNED = True
EXPORT_FP16_PRUNED = True

# Edge TPU Compilation
COMPILE_EDGE_TPU = True          # Compile INT8 models for Coral TPU

# Pruning Configuration (if enabled)
PRUNING_INITIAL_SPARSITY = 0.0   # Start with 0% sparsity
PRUNING_FINAL_SPARSITY = 0.5     # End with 50% sparsity
PRUNING_BEGIN_STEP = 0
PRUNING_END_STEP = 1000
PRUNING_FREQUENCY = 100

# %% [markdown]
# # 各パス指定

# %%
dataset = 'model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.hdf5'

# %% [markdown]
# # 分類数設定

# %%
NUM_CLASSES = 3

# %% [markdown]
# # 学習データ読み込み

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# # モデル構築

# %%
# Check if pruning is enabled
USE_PRUNING = EXPORT_INT8_PRUNED or EXPORT_FP16_PRUNED

if USE_PRUNING:
    print("⚙️  Training with pruning enabled")
    import tensorflow_model_optimization as tfmot
    
    # Build base model
    base_model = tf.keras.models.Sequential([
        tf.keras.layers.Input((21 * 2, )),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(20, activation='relu'),
        tf.keras.layers.Dropout(0.4),
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    
    # Apply pruning
    pruning_params = {
        'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(
            initial_sparsity=PRUNING_INITIAL_SPARSITY,
            final_sparsity=PRUNING_FINAL_SPARSITY,
            begin_step=PRUNING_BEGIN_STEP,
            end_step=PRUNING_END_STEP,
            frequency=PRUNING_FREQUENCY
        )
    }
    
    model = tfmot.sparsity.keras.prune_low_magnitude(base_model, **pruning_params)
    print(f"  Pruning: {PRUNING_INITIAL_SPARSITY*100}% → {PRUNING_FINAL_SPARSITY*100}% sparsity")
else:
    print("⚙️  Training without pruning")
    model = tf.keras.models.Sequential([
        tf.keras.layers.Input((21 * 2, )),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(20, activation='relu'),
        tf.keras.layers.Dropout(0.4),
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
# Out:
# ⚙️  Training with pruning enabled
#   Pruning: 0.0% → 50.0% sparsity

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prune_low_magnitude_dropout  (None, 42)               1
#  _2 (PruneLowMagnitude)
#
#  prune_low_magnitude_dense_3  (None, 20)               1702
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_dropout  (None, 20)               1
#  _3 (PruneLowMagnitude)
#
#  prune_low_magnitude_dense_4  (None, 10)               412
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_dense_5  (None, 3)                65
#   (PruneLowMagnitude)
#
# =================================================================
# Total params: 2,181
# Trainable params: 1,103
# Non-trainable params: 1,078
# _________________________________________________________________

# %%
# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# Add pruning callback if pruning is enabled
callbacks_list = [cp_callback, es_callback]
if USE_PRUNING:
    import tensorflow_model_optimization as tfmot
    pruning_callback = tfmot.sparsity.keras.UpdatePruningStep()
    callbacks_list.append(pruning_callback)
    print("Added pruning callback")
# Out:
# Added pruning callback

# %%
# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # モデル訓練

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=callbacks_list
)
# Out:
# Epoch 1/1000
#  1/27 [>.............................] - ETA: 22s - loss: 1.2983 - accuracy: 0.2812
# Epoch 1: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 1s 10ms/step - loss: 1.1742 - accuracy: 0.3233 - val_loss: 1.0892 - val_accuracy: 0.3845
# Epoch 2/1000
# 25/27 [==========================>...] - ETA: 0s - loss: 1.0871 - accuracy: 0.3781
# Epoch 2: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 1.0872 - accuracy: 0.3770 - val_loss: 1.0541 - val_accuracy: 0.4007
# Epoch 3/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 1.0666 - accuracy: 0.3980
# Epoch 3: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 1.0658 - accuracy: 0.4049 - val_loss: 1.0270 - val_accuracy: 0.4340
# Epoch 4/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 1.0379 - accuracy: 0.4461
# Epoch 4: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 1.0363 - accuracy: 0.4471 - val_loss: 0.9874 - val_accuracy: 0.5130
# Epoch 5/1000
# 22/27 [=======================>......] - ETA: 0s - loss: 1.0144 - accuracy: 0.4773
# Epoch 5: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 12ms/step - loss: 1.0108 - accuracy: 0.4789 - val_loss: 0.9413 - val_accuracy: 0.5867
# Epoch 6/1000
# 16/27 [================>.............] - ETA: 0s - loss: 0.9839 - accuracy: 0.5117
# Epoch 6: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.9750 - accuracy: 0.5175 - val_loss: 0.8917 - val_accuracy: 0.6757
# Epoch 7/1000
# 27/27 [==============================] - ETA: 0s - loss: 0.9419 - accuracy: 0.5487
# Epoch 7: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 4ms/step - loss: 0.9419 - accuracy: 0.5487 - val_loss: 0.8396 - val_accuracy: 0.7098
# Epoch 8/1000
# 23/27 [========================>.....] - ETA: 0s - loss: 0.9147 - accuracy: 0.5615
# Epoch 8: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.9155 - accuracy: 0.5574 - val_loss: 0.7929 - val_accuracy: 0.7260
# Epoch 9/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.8787 - accuracy: 0.5703
# Epoch 9: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 3ms/step - loss: 0.8885 - accuracy: 0.5685 - val_loss: 0.7563 - val_accuracy: 0.7547
# Epoch 10/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.8733 - accuracy: 0.5894
# Epoch 10: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.8661 - accuracy: 0.5966 - val_loss: 0.7216 - val_accuracy: 0.7754
# Epoch 11/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.8373 - accuracy: 0.6094
# Epoch 11: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 4ms/step - loss: 0.8391 - accuracy: 0.6233 - val_loss: 0.6899 - val_accuracy: 0.7754
# Epoch 12/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.7821 - accuracy: 0.6719
# Epoch 12: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 2ms/step - loss: 0.8037 - accuracy: 0.6356 - val_loss: 0.6447 - val_accuracy: 0.7898
# Epoch 13/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.8465 - accuracy: 0.5781
# Epoch 13: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7879 - accuracy: 0.6389 - val_loss: 0.6217 - val_accuracy: 0.8041
# Epoch 14/1000
# 27/27 [==============================] - ETA: 0s - loss: 0.7809 - accuracy: 0.6389
# Epoch 14: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.7809 - accuracy: 0.6389 - val_loss: 0.5992 - val_accuracy: 0.8194
# Epoch 15/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.7129 - accuracy: 0.6250
# Epoch 15: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7499 - accuracy: 0.6659 - val_loss: 0.5843 - val_accuracy: 0.8158
# Epoch 16/1000
# 26/27 [===========================>..] - ETA: 0s - loss: 0.7413 - accuracy: 0.6710
# Epoch 16: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7413 - accuracy: 0.6707 - val_loss: 0.5568 - val_accuracy: 0.8518
# Epoch 17/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.8121 - accuracy: 0.6172
# Epoch 17: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.7259 - accuracy: 0.6815 - val_loss: 0.5360 - val_accuracy: 0.8580
# Epoch 18/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.7006 - accuracy: 0.7062
# Epoch 18: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.7112 - accuracy: 0.6991 - val_loss: 0.5153 - val_accuracy: 0.8661
# Epoch 19/1000
# 15/27 [===============>..............] - ETA: 0s - loss: 0.7101 - accuracy: 0.6932
# Epoch 19: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6992 - accuracy: 0.7087 - val_loss: 0.5066 - val_accuracy: 0.9012
# Epoch 20/1000
# 26/27 [===========================>..] - ETA: 0s - loss: 0.6794 - accuracy: 0.7151
# Epoch 20: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6801 - accuracy: 0.7144 - val_loss: 0.4845 - val_accuracy: 0.8949
# Epoch 21/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.6878 - accuracy: 0.7066
# Epoch 21: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6881 - accuracy: 0.7051 - val_loss: 0.4698 - val_accuracy: 0.8949
# Epoch 22/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.6880 - accuracy: 0.7008
# Epoch 22: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6791 - accuracy: 0.7111 - val_loss: 0.4548 - val_accuracy: 0.8958
# Epoch 23/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.6702 - accuracy: 0.7086
# Epoch 23: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.6730 - accuracy: 0.7060 - val_loss: 0.4402 - val_accuracy: 0.9048
# Epoch 24/1000
# 15/27 [===============>..............] - ETA: 0s - loss: 0.6544 - accuracy: 0.7214
# Epoch 24: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6529 - accuracy: 0.7246 - val_loss: 0.4324 - val_accuracy: 0.9066
# Epoch 25/1000
# 15/27 [===============>..............] - ETA: 0s - loss: 0.6575 - accuracy: 0.7214
# Epoch 25: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6475 - accuracy: 0.7276 - val_loss: 0.4240 - val_accuracy: 0.9173
# Epoch 26/1000
# 24/27 [=========================>....] - ETA: 0s - loss: 0.6381 - accuracy: 0.7266
# Epoch 26: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6391 - accuracy: 0.7249 - val_loss: 0.4244 - val_accuracy: 0.9317
# Epoch 27/1000
# 27/27 [==============================] - ETA: 0s - loss: 0.6475 - accuracy: 0.7375
# Epoch 27: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6475 - accuracy: 0.7375 - val_loss: 0.4145 - val_accuracy: 0.9389
# Epoch 28/1000
# 23/27 [========================>.....] - ETA: 0s - loss: 0.6325 - accuracy: 0.7429
# Epoch 28: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6323 - accuracy: 0.7450 - val_loss: 0.4047 - val_accuracy: 0.9398
# Epoch 29/1000
# 14/27 [==============>...............] - ETA: 0s - loss: 0.6475 - accuracy: 0.7227
# Epoch 29: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6399 - accuracy: 0.7249 - val_loss: 0.3939 - val_accuracy: 0.9407
# Epoch 30/1000
# 12/27 [============>.................] - ETA: 0s - loss: 0.6070 - accuracy: 0.7546
# Epoch 30: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6174 - accuracy: 0.7492 - val_loss: 0.3854 - val_accuracy: 0.9344
# Epoch 31/1000
# 22/27 [=======================>......] - ETA: 0s - loss: 0.6131 - accuracy: 0.7464
# Epoch 31: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6129 - accuracy: 0.7453 - val_loss: 0.3740 - val_accuracy: 0.9398
# Epoch 32/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.6123 - accuracy: 0.7539
# Epoch 32: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6176 - accuracy: 0.7501 - val_loss: 0.3699 - val_accuracy: 0.9398
# Epoch 33/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.5937 - accuracy: 0.7422
# Epoch 33: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6225 - accuracy: 0.7411 - val_loss: 0.3694 - val_accuracy: 0.9407
# Epoch 34/1000
# 27/27 [==============================] - ETA: 0s - loss: 0.6037 - accuracy: 0.7594
# Epoch 34: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6037 - accuracy: 0.7594 - val_loss: 0.3599 - val_accuracy: 0.9398
# Epoch 35/1000
# 23/27 [========================>.....] - ETA: 0s - loss: 0.6109 - accuracy: 0.7486
# Epoch 35: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6128 - accuracy: 0.7471 - val_loss: 0.3541 - val_accuracy: 0.9380
# Epoch 36/1000
# 12/27 [============>.................] - ETA: 0s - loss: 0.5976 - accuracy: 0.7422
# Epoch 36: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6107 - accuracy: 0.7438 - val_loss: 0.3487 - val_accuracy: 0.9416
# Epoch 37/1000
# 25/27 [==========================>...] - ETA: 0s - loss: 0.6045 - accuracy: 0.7456
# Epoch 37: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5996 - accuracy: 0.7489 - val_loss: 0.3457 - val_accuracy: 0.9425
# Epoch 38/1000
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5861 - accuracy: 0.7578
# Epoch 38: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5860 - accuracy: 0.7576 - val_loss: 0.3371 - val_accuracy: 0.9479
# Epoch 39/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.5395 - accuracy: 0.7578
# Epoch 39: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5742 - accuracy: 0.7567 - val_loss: 0.3285 - val_accuracy: 0.9497
# Epoch 40/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.5807 - accuracy: 0.7652
# Epoch 40: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5788 - accuracy: 0.7660 - val_loss: 0.3221 - val_accuracy: 0.9479
# Epoch 41/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.5963 - accuracy: 0.7891
# Epoch 41: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5870 - accuracy: 0.7576 - val_loss: 0.3192 - val_accuracy: 0.9461
# Epoch 42/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.6671 - accuracy: 0.7344
# Epoch 42: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5845 - accuracy: 0.7663 - val_loss: 0.3170 - val_accuracy: 0.9488
# Epoch 43/1000
# 25/27 [==========================>...] - ETA: 0s - loss: 0.5725 - accuracy: 0.7600
# Epoch 43: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5739 - accuracy: 0.7597 - val_loss: 0.3148 - val_accuracy: 0.9506
# Epoch 44/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.5699 - accuracy: 0.7668
# Epoch 44: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5805 - accuracy: 0.7627 - val_loss: 0.3144 - val_accuracy: 0.9497
# Epoch 45/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.5715 - accuracy: 0.7734
# Epoch 45: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5826 - accuracy: 0.7654 - val_loss: 0.3125 - val_accuracy: 0.9461
# Epoch 46/1000
# 22/27 [=======================>......] - ETA: 0s - loss: 0.5698 - accuracy: 0.7699
# Epoch 46: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5740 - accuracy: 0.7690 - val_loss: 0.3119 - val_accuracy: 0.9506
# Epoch 47/1000
# 16/27 [================>.............] - ETA: 0s - loss: 0.5650 - accuracy: 0.7798
# Epoch 47: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5601 - accuracy: 0.7749 - val_loss: 0.3039 - val_accuracy: 0.9542
# Epoch 48/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.5639 - accuracy: 0.7711
# Epoch 48: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5644 - accuracy: 0.7702 - val_loss: 0.3006 - val_accuracy: 0.9542
# Epoch 49/1000
# 23/27 [========================>.....] - ETA: 0s - loss: 0.5591 - accuracy: 0.7833
# Epoch 49: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.5554 - accuracy: 0.7866 - val_loss: 0.2978 - val_accuracy: 0.9524
# Epoch 50/1000
# 24/27 [=========================>....] - ETA: 0s - loss: 0.5539 - accuracy: 0.7757
# Epoch 50: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.5489 - accuracy: 0.7791 - val_loss: 0.2914 - val_accuracy: 0.9551
# Epoch 51/1000
# 22/27 [=======================>......] - ETA: 0s - loss: 0.5674 - accuracy: 0.7656
# Epoch 51: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5653 - accuracy: 0.7699 - val_loss: 0.2937 - val_accuracy: 0.9551
# Epoch 52/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.5516 - accuracy: 0.7803
# Epoch 52: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5528 - accuracy: 0.7794 - val_loss: 0.2903 - val_accuracy: 0.9533
# Epoch 53/1000
# 22/27 [=======================>......] - ETA: 0s - loss: 0.5536 - accuracy: 0.7791
# Epoch 53: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5551 - accuracy: 0.7773 - val_loss: 0.2875 - val_accuracy: 0.9569
# Epoch 54/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.5492 - accuracy: 0.7738
# Epoch 54: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5424 - accuracy: 0.7767 - val_loss: 0.2843 - val_accuracy: 0.9578
# Epoch 55/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.5503 - accuracy: 0.7752
# Epoch 55: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5555 - accuracy: 0.7690 - val_loss: 0.2820 - val_accuracy: 0.9551
# Epoch 56/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.5429 - accuracy: 0.7849
# Epoch 56: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5417 - accuracy: 0.7848 - val_loss: 0.2822 - val_accuracy: 0.9560
# Epoch 57/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.5370 - accuracy: 0.7836
# Epoch 57: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5466 - accuracy: 0.7794 - val_loss: 0.2811 - val_accuracy: 0.9560
# Epoch 58/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.5504 - accuracy: 0.7855
# Epoch 58: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5354 - accuracy: 0.7941 - val_loss: 0.2766 - val_accuracy: 0.9569
# Epoch 59/1000
# 25/27 [==========================>...] - ETA: 0s - loss: 0.5352 - accuracy: 0.7831
# Epoch 59: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5341 - accuracy: 0.7827 - val_loss: 0.2753 - val_accuracy: 0.9578
# Epoch 60/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.5548 - accuracy: 0.7697
# Epoch 60: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5501 - accuracy: 0.7737 - val_loss: 0.2708 - val_accuracy: 0.9515
# Epoch 61/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.5332 - accuracy: 0.7821
# Epoch 61: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5337 - accuracy: 0.7845 - val_loss: 0.2688 - val_accuracy: 0.9542
# Epoch 62/1000
# 16/27 [================>.............] - ETA: 0s - loss: 0.5158 - accuracy: 0.7949
# Epoch 62: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5176 - accuracy: 0.7929 - val_loss: 0.2699 - val_accuracy: 0.9587
# Epoch 63/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.5309 - accuracy: 0.7894
# Epoch 63: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5400 - accuracy: 0.7842 - val_loss: 0.2692 - val_accuracy: 0.9587
# Epoch 64/1000
# 23/27 [========================>.....] - ETA: 0s - loss: 0.5474 - accuracy: 0.7792
# Epoch 64: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5418 - accuracy: 0.7833 - val_loss: 0.2686 - val_accuracy: 0.9578
# Epoch 65/1000
# 25/27 [==========================>...] - ETA: 0s - loss: 0.5216 - accuracy: 0.8034
# Epoch 65: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5231 - accuracy: 0.8019 - val_loss: 0.2666 - val_accuracy: 0.9569
# Epoch 66/1000
# 14/27 [==============>...............] - ETA: 0s - loss: 0.5173 - accuracy: 0.8008
# Epoch 66: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5207 - accuracy: 0.7941 - val_loss: 0.2642 - val_accuracy: 0.9587
# Epoch 67/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.5224 - accuracy: 0.7910
# Epoch 67: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5241 - accuracy: 0.7920 - val_loss: 0.2622 - val_accuracy: 0.9587
# Epoch 68/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4999 - accuracy: 0.8043
# Epoch 68: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.5038 - accuracy: 0.8019 - val_loss: 0.2580 - val_accuracy: 0.9596
# Epoch 69/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.5369 - accuracy: 0.7836
# Epoch 69: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.5447 - accuracy: 0.7818 - val_loss: 0.2577 - val_accuracy: 0.9605
# Epoch 70/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.5525 - accuracy: 0.7794
# Epoch 70: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5405 - accuracy: 0.7869 - val_loss: 0.2634 - val_accuracy: 0.9605
# Epoch 71/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.5076 - accuracy: 0.8074
# Epoch 71: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5185 - accuracy: 0.7959 - val_loss: 0.2586 - val_accuracy: 0.9596
# Epoch 72/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.5091 - accuracy: 0.7908
# Epoch 72: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5009 - accuracy: 0.7902 - val_loss: 0.2543 - val_accuracy: 0.9614
# Epoch 73/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.5157 - accuracy: 0.7937
# Epoch 73: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5182 - accuracy: 0.7929 - val_loss: 0.2510 - val_accuracy: 0.9632
# Epoch 74/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.5084 - accuracy: 0.8021
# Epoch 74: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5113 - accuracy: 0.7989 - val_loss: 0.2514 - val_accuracy: 0.9614
# Epoch 75/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.5267 - accuracy: 0.7943
# Epoch 75: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5248 - accuracy: 0.7905 - val_loss: 0.2501 - val_accuracy: 0.9605
# Epoch 76/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4976 - accuracy: 0.8072
# Epoch 76: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5041 - accuracy: 0.8046 - val_loss: 0.2515 - val_accuracy: 0.9623
# Epoch 77/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4945 - accuracy: 0.8010
# Epoch 77: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.5032 - accuracy: 0.8016 - val_loss: 0.2489 - val_accuracy: 0.9632
# Epoch 78/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.5235 - accuracy: 0.8030
# Epoch 78: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5210 - accuracy: 0.8010 - val_loss: 0.2491 - val_accuracy: 0.9605
# Epoch 79/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.5027 - accuracy: 0.8016
# Epoch 79: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5049 - accuracy: 0.8031 - val_loss: 0.2488 - val_accuracy: 0.9623
# Epoch 80/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.5238 - accuracy: 0.7932
# Epoch 80: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5243 - accuracy: 0.7917 - val_loss: 0.2508 - val_accuracy: 0.9614
# Epoch 81/1000
# 25/27 [==========================>...] - ETA: 0s - loss: 0.5087 - accuracy: 0.7984
# Epoch 81: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5057 - accuracy: 0.8001 - val_loss: 0.2516 - val_accuracy: 0.9605
# Epoch 82/1000
# 27/27 [==============================] - ETA: 0s - loss: 0.5079 - accuracy: 0.7971
# Epoch 82: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5079 - accuracy: 0.7971 - val_loss: 0.2453 - val_accuracy: 0.9623
# Epoch 83/1000
# 16/27 [================>.............] - ETA: 0s - loss: 0.5291 - accuracy: 0.7983
# Epoch 83: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5227 - accuracy: 0.7962 - val_loss: 0.2461 - val_accuracy: 0.9641
# Epoch 84/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.5073 - accuracy: 0.7993
# Epoch 84: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5121 - accuracy: 0.8010 - val_loss: 0.2486 - val_accuracy: 0.9623
# Epoch 85/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4819 - accuracy: 0.8086
# Epoch 85: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4834 - accuracy: 0.8103 - val_loss: 0.2451 - val_accuracy: 0.9623
# Epoch 86/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.5040 - accuracy: 0.8067
# Epoch 86: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4985 - accuracy: 0.8043 - val_loss: 0.2456 - val_accuracy: 0.9605
# Epoch 87/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4842 - accuracy: 0.8084
# Epoch 87: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4858 - accuracy: 0.8118 - val_loss: 0.2424 - val_accuracy: 0.9623
# Epoch 88/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.5045 - accuracy: 0.7944
# Epoch 88: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4971 - accuracy: 0.8016 - val_loss: 0.2393 - val_accuracy: 0.9632
# Epoch 89/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4681 - accuracy: 0.8187
# Epoch 89: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4856 - accuracy: 0.8082 - val_loss: 0.2350 - val_accuracy: 0.9614
# Epoch 90/1000
# 23/27 [========================>.....] - ETA: 0s - loss: 0.4914 - accuracy: 0.8047
# Epoch 90: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4896 - accuracy: 0.8067 - val_loss: 0.2352 - val_accuracy: 0.9632
# Epoch 91/1000
# 27/27 [==============================] - ETA: 0s - loss: 0.5002 - accuracy: 0.8070
# Epoch 91: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5002 - accuracy: 0.8070 - val_loss: 0.2355 - val_accuracy: 0.9650
# Epoch 92/1000
# 26/27 [===========================>..] - ETA: 0s - loss: 0.4719 - accuracy: 0.8119
# Epoch 92: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4714 - accuracy: 0.8121 - val_loss: 0.2373 - val_accuracy: 0.9650
# Epoch 93/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4834 - accuracy: 0.8103
# Epoch 93: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4979 - accuracy: 0.8034 - val_loss: 0.2320 - val_accuracy: 0.9650
# Epoch 94/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4929 - accuracy: 0.7992
# Epoch 94: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4944 - accuracy: 0.7998 - val_loss: 0.2335 - val_accuracy: 0.9650
# Epoch 95/1000
# 24/27 [=========================>....] - ETA: 0s - loss: 0.4964 - accuracy: 0.8047
# Epoch 95: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4899 - accuracy: 0.8082 - val_loss: 0.2355 - val_accuracy: 0.9623
# Epoch 96/1000
# 12/27 [============>.................] - ETA: 0s - loss: 0.4855 - accuracy: 0.8171
# Epoch 96: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4742 - accuracy: 0.8211 - val_loss: 0.2314 - val_accuracy: 0.9623
# Epoch 97/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4952 - accuracy: 0.8074
# Epoch 97: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4905 - accuracy: 0.8082 - val_loss: 0.2333 - val_accuracy: 0.9632
# Epoch 98/1000
# 27/27 [==============================] - ETA: 0s - loss: 0.4864 - accuracy: 0.8097
# Epoch 98: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4864 - accuracy: 0.8097 - val_loss: 0.2346 - val_accuracy: 0.9632
# Epoch 99/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4687 - accuracy: 0.8092
# Epoch 99: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4674 - accuracy: 0.8109 - val_loss: 0.2324 - val_accuracy: 0.9641
# Epoch 100/1000
# 23/27 [========================>.....] - ETA: 0s - loss: 0.4957 - accuracy: 0.7979
# Epoch 100: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4877 - accuracy: 0.8046 - val_loss: 0.2354 - val_accuracy: 0.9659
# Epoch 101/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4811 - accuracy: 0.8187
# Epoch 101: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 12ms/step - loss: 0.4930 - accuracy: 0.8142 - val_loss: 0.2364 - val_accuracy: 0.9650
# Epoch 102/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.4620 - accuracy: 0.8160
# Epoch 102: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4753 - accuracy: 0.8094 - val_loss: 0.2326 - val_accuracy: 0.9641
# Epoch 103/1000
# 23/27 [========================>.....] - ETA: 0s - loss: 0.4628 - accuracy: 0.8101
# Epoch 103: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4645 - accuracy: 0.8106 - val_loss: 0.2316 - val_accuracy: 0.9641
# Epoch 104/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4780 - accuracy: 0.8093
# Epoch 104: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4701 - accuracy: 0.8103 - val_loss: 0.2300 - val_accuracy: 0.9632
# Epoch 105/1000
# 22/27 [=======================>......] - ETA: 0s - loss: 0.4837 - accuracy: 0.8097
# Epoch 105: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4827 - accuracy: 0.8082 - val_loss: 0.2275 - val_accuracy: 0.9632
# Epoch 106/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.4848 - accuracy: 0.8147
# Epoch 106: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4747 - accuracy: 0.8199 - val_loss: 0.2293 - val_accuracy: 0.9632
# Epoch 107/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4712 - accuracy: 0.8174
# Epoch 107: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.4704 - accuracy: 0.8154 - val_loss: 0.2229 - val_accuracy: 0.9641
# Epoch 108/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4556 - accuracy: 0.8199
# Epoch 108: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4529 - accuracy: 0.8202 - val_loss: 0.2193 - val_accuracy: 0.9641
# Epoch 109/1000
# 27/27 [==============================] - ETA: 0s - loss: 0.4765 - accuracy: 0.8112
# Epoch 109: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4765 - accuracy: 0.8112 - val_loss: 0.2191 - val_accuracy: 0.9641
# Epoch 110/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4626 - accuracy: 0.8162
# Epoch 110: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4656 - accuracy: 0.8151 - val_loss: 0.2230 - val_accuracy: 0.9650
# Epoch 111/1000
# 12/27 [============>.................] - ETA: 0s - loss: 0.4618 - accuracy: 0.8203
# Epoch 111: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4614 - accuracy: 0.8220 - val_loss: 0.2250 - val_accuracy: 0.9650
# Epoch 112/1000
# 15/27 [===============>..............] - ETA: 0s - loss: 0.4544 - accuracy: 0.8292
# Epoch 112: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4523 - accuracy: 0.8304 - val_loss: 0.2285 - val_accuracy: 0.9596
# Epoch 113/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4393 - accuracy: 0.8263
# Epoch 113: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4492 - accuracy: 0.8265 - val_loss: 0.2198 - val_accuracy: 0.9614
# Epoch 114/1000
# 25/27 [==========================>...] - ETA: 0s - loss: 0.4879 - accuracy: 0.8066
# Epoch 114: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4908 - accuracy: 0.8040 - val_loss: 0.2246 - val_accuracy: 0.9641
# Epoch 115/1000
# 24/27 [=========================>....] - ETA: 0s - loss: 0.4793 - accuracy: 0.8148
# Epoch 115: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4834 - accuracy: 0.8154 - val_loss: 0.2276 - val_accuracy: 0.9632
# Epoch 116/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4696 - accuracy: 0.8143
# Epoch 116: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4690 - accuracy: 0.8148 - val_loss: 0.2288 - val_accuracy: 0.9650
# Epoch 117/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4550 - accuracy: 0.8230
# Epoch 117: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4623 - accuracy: 0.8238 - val_loss: 0.2239 - val_accuracy: 0.9668
# Epoch 118/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4609 - accuracy: 0.8151
# Epoch 118: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4613 - accuracy: 0.8184 - val_loss: 0.2261 - val_accuracy: 0.9641
# Epoch 119/1000
# 10/27 [==========>...................] - ETA: 0s - loss: 0.4619 - accuracy: 0.8266
# Epoch 119: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.4616 - accuracy: 0.8196 - val_loss: 0.2263 - val_accuracy: 0.9650
# Epoch 120/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4689 - accuracy: 0.8188
# Epoch 120: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4720 - accuracy: 0.8205 - val_loss: 0.2213 - val_accuracy: 0.9650
# Epoch 121/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4647 - accuracy: 0.8177
# Epoch 121: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4597 - accuracy: 0.8217 - val_loss: 0.2190 - val_accuracy: 0.9641
# Epoch 122/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4654 - accuracy: 0.8302
# Epoch 122: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4649 - accuracy: 0.8262 - val_loss: 0.2198 - val_accuracy: 0.9641
# Epoch 123/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4461 - accuracy: 0.8229
# Epoch 123: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4495 - accuracy: 0.8229 - val_loss: 0.2205 - val_accuracy: 0.9641
# Epoch 124/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4561 - accuracy: 0.8219
# Epoch 124: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4565 - accuracy: 0.8187 - val_loss: 0.2171 - val_accuracy: 0.9632
# Epoch 125/1000
# 16/27 [================>.............] - ETA: 0s - loss: 0.4778 - accuracy: 0.8071
# Epoch 125: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.4605 - accuracy: 0.8196 - val_loss: 0.2217 - val_accuracy: 0.9641
# Epoch 126/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4799 - accuracy: 0.8170
# Epoch 126: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4761 - accuracy: 0.8130 - val_loss: 0.2268 - val_accuracy: 0.9650
# Epoch 127/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.4704 - accuracy: 0.8181
# Epoch 127: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4616 - accuracy: 0.8193 - val_loss: 0.2247 - val_accuracy: 0.9650
# Epoch 128/1000
# 16/27 [================>.............] - ETA: 0s - loss: 0.4515 - accuracy: 0.8330
# Epoch 128: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4474 - accuracy: 0.8313 - val_loss: 0.2242 - val_accuracy: 0.9650
# Epoch 129/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.4687 - accuracy: 0.8164
# Epoch 129: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4582 - accuracy: 0.8202 - val_loss: 0.2196 - val_accuracy: 0.9659
# Epoch 130/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.4103 - accuracy: 0.8906
# Epoch 130: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4650 - accuracy: 0.8232 - val_loss: 0.2216 - val_accuracy: 0.9659
# Epoch 131/1000
# 22/27 [=======================>......] - ETA: 0s - loss: 0.4506 - accuracy: 0.8239
# Epoch 131: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4511 - accuracy: 0.8250 - val_loss: 0.2217 - val_accuracy: 0.9650
# Epoch 132/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4545 - accuracy: 0.8285
# Epoch 132: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4543 - accuracy: 0.8289 - val_loss: 0.2259 - val_accuracy: 0.9668
# Epoch 133/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.4601 - accuracy: 0.8247
# Epoch 133: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4580 - accuracy: 0.8214 - val_loss: 0.2212 - val_accuracy: 0.9668
# Epoch 134/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4530 - accuracy: 0.8240
# Epoch 134: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4601 - accuracy: 0.8211 - val_loss: 0.2227 - val_accuracy: 0.9650
# Epoch 135/1000
# 24/27 [=========================>....] - ETA: 0s - loss: 0.4622 - accuracy: 0.8180
# Epoch 135: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4630 - accuracy: 0.8172 - val_loss: 0.2244 - val_accuracy: 0.9650
# Epoch 136/1000
# 25/27 [==========================>...] - ETA: 0s - loss: 0.4506 - accuracy: 0.8213
# Epoch 136: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4473 - accuracy: 0.8223 - val_loss: 0.2219 - val_accuracy: 0.9650
# Epoch 137/1000
# 26/27 [===========================>..] - ETA: 0s - loss: 0.4639 - accuracy: 0.8197
# Epoch 137: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4637 - accuracy: 0.8196 - val_loss: 0.2214 - val_accuracy: 0.9650
# Epoch 138/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4581 - accuracy: 0.8208
# Epoch 138: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4541 - accuracy: 0.8208 - val_loss: 0.2185 - val_accuracy: 0.9677
# Epoch 139/1000
# 15/27 [===============>..............] - ETA: 0s - loss: 0.4504 - accuracy: 0.8229
# Epoch 139: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4450 - accuracy: 0.8307 - val_loss: 0.2186 - val_accuracy: 0.9668
# Epoch 140/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4337 - accuracy: 0.8281
# Epoch 140: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4339 - accuracy: 0.8322 - val_loss: 0.2201 - val_accuracy: 0.9668
# Epoch 141/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.4546 - accuracy: 0.8234
# Epoch 141: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4363 - accuracy: 0.8304 - val_loss: 0.2189 - val_accuracy: 0.9659
# Epoch 142/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4310 - accuracy: 0.8300
# Epoch 142: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4385 - accuracy: 0.8283 - val_loss: 0.2176 - val_accuracy: 0.9668
# Epoch 143/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4312 - accuracy: 0.8375
# Epoch 143: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4372 - accuracy: 0.8343 - val_loss: 0.2163 - val_accuracy: 0.9650
# Epoch 144/1000
# 23/27 [========================>.....] - ETA: 0s - loss: 0.4518 - accuracy: 0.8203
# Epoch 144: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4560 - accuracy: 0.8184 - val_loss: 0.2163 - val_accuracy: 0.9659
# Epoch 145/1000
# 16/27 [================>.............] - ETA: 0s - loss: 0.4436 - accuracy: 0.8354
# Epoch 145: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4517 - accuracy: 0.8304 - val_loss: 0.2174 - val_accuracy: 0.9641
# Epoch 146/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.4131 - accuracy: 0.8516
# Epoch 146: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4480 - accuracy: 0.8259 - val_loss: 0.2168 - val_accuracy: 0.9668
# Epoch 147/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4347 - accuracy: 0.8363
# Epoch 147: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4278 - accuracy: 0.8361 - val_loss: 0.2162 - val_accuracy: 0.9659
# Epoch 148/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4414 - accuracy: 0.8203
# Epoch 148: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4436 - accuracy: 0.8199 - val_loss: 0.2155 - val_accuracy: 0.9677
# Epoch 149/1000
# 15/27 [===============>..............] - ETA: 0s - loss: 0.4548 - accuracy: 0.8255
# Epoch 149: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.4488 - accuracy: 0.8304 - val_loss: 0.2198 - val_accuracy: 0.9677
# Epoch 150/1000
# 16/27 [================>.............] - ETA: 0s - loss: 0.4463 - accuracy: 0.8311
# Epoch 150: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4407 - accuracy: 0.8331 - val_loss: 0.2247 - val_accuracy: 0.9668
# Epoch 151/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4504 - accuracy: 0.8226
# Epoch 151: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.4431 - accuracy: 0.8298 - val_loss: 0.2185 - val_accuracy: 0.9668
# Epoch 152/1000
# 14/27 [==============>...............] - ETA: 0s - loss: 0.4486 - accuracy: 0.8326
# Epoch 152: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4465 - accuracy: 0.8292 - val_loss: 0.2191 - val_accuracy: 0.9659
# Epoch 153/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.4164 - accuracy: 0.8398
# Epoch 153: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4223 - accuracy: 0.8388 - val_loss: 0.2086 - val_accuracy: 0.9686
# Epoch 154/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.4345 - accuracy: 0.8299
# Epoch 154: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4330 - accuracy: 0.8334 - val_loss: 0.2129 - val_accuracy: 0.9668
# Epoch 155/1000
# 11/27 [===========>..................] - ETA: 0s - loss: 0.4646 - accuracy: 0.8232
# Epoch 155: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 8ms/step - loss: 0.4493 - accuracy: 0.8265 - val_loss: 0.2176 - val_accuracy: 0.9686
# Epoch 156/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4449 - accuracy: 0.8296
# Epoch 156: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4417 - accuracy: 0.8268 - val_loss: 0.2170 - val_accuracy: 0.9677
# Epoch 157/1000
# 15/27 [===============>..............] - ETA: 0s - loss: 0.4238 - accuracy: 0.8438
# Epoch 157: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4398 - accuracy: 0.8376 - val_loss: 0.2124 - val_accuracy: 0.9668
# Epoch 158/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4190 - accuracy: 0.8483
# Epoch 158: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4234 - accuracy: 0.8457 - val_loss: 0.2191 - val_accuracy: 0.9659
# Epoch 159/1000
# 23/27 [========================>.....] - ETA: 0s - loss: 0.4247 - accuracy: 0.8302
# Epoch 159: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4262 - accuracy: 0.8286 - val_loss: 0.2195 - val_accuracy: 0.9659
# Epoch 160/1000
# 27/27 [==============================] - ETA: 0s - loss: 0.4337 - accuracy: 0.8331
# Epoch 160: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4337 - accuracy: 0.8331 - val_loss: 0.2163 - val_accuracy: 0.9677
# Epoch 161/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4240 - accuracy: 0.8395
# Epoch 161: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4284 - accuracy: 0.8373 - val_loss: 0.2164 - val_accuracy: 0.9686
# Epoch 162/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.4519 - accuracy: 0.8286
# Epoch 162: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4576 - accuracy: 0.8286 - val_loss: 0.2188 - val_accuracy: 0.9686
# Epoch 163/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4700 - accuracy: 0.8172
# Epoch 163: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4569 - accuracy: 0.8226 - val_loss: 0.2207 - val_accuracy: 0.9668
# Epoch 164/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4406 - accuracy: 0.8332
# Epoch 164: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4391 - accuracy: 0.8286 - val_loss: 0.2186 - val_accuracy: 0.9704
# Epoch 165/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4298 - accuracy: 0.8355
# Epoch 165: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4296 - accuracy: 0.8373 - val_loss: 0.2259 - val_accuracy: 0.9677
# Epoch 166/1000
# 16/27 [================>.............] - ETA: 0s - loss: 0.4332 - accuracy: 0.8423
# Epoch 166: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4408 - accuracy: 0.8385 - val_loss: 0.2240 - val_accuracy: 0.9677
# Epoch 167/1000
# 22/27 [=======================>......] - ETA: 0s - loss: 0.4311 - accuracy: 0.8391
# Epoch 167: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.4337 - accuracy: 0.8376 - val_loss: 0.2318 - val_accuracy: 0.9668
# Epoch 168/1000
# 22/27 [=======================>......] - ETA: 0s - loss: 0.4235 - accuracy: 0.8342
# Epoch 168: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4163 - accuracy: 0.8373 - val_loss: 0.2224 - val_accuracy: 0.9686
# Epoch 169/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4194 - accuracy: 0.8339
# Epoch 169: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4236 - accuracy: 0.8328 - val_loss: 0.2139 - val_accuracy: 0.9695
# Epoch 170/1000
# 25/27 [==========================>...] - ETA: 0s - loss: 0.4237 - accuracy: 0.8406
# Epoch 170: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4277 - accuracy: 0.8391 - val_loss: 0.2062 - val_accuracy: 0.9677
# Epoch 171/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4623 - accuracy: 0.8139
# Epoch 171: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4427 - accuracy: 0.8268 - val_loss: 0.2189 - val_accuracy: 0.9686
# Epoch 172/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4313 - accuracy: 0.8281
# Epoch 172: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4352 - accuracy: 0.8286 - val_loss: 0.2167 - val_accuracy: 0.9695
# Epoch 173/1000
# 22/27 [=======================>......] - ETA: 0s - loss: 0.4115 - accuracy: 0.8452
# Epoch 173: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4163 - accuracy: 0.8418 - val_loss: 0.2196 - val_accuracy: 0.9686
# Epoch 174/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4332 - accuracy: 0.8421
# Epoch 174: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4342 - accuracy: 0.8397 - val_loss: 0.2204 - val_accuracy: 0.9677
# Epoch 175/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4296 - accuracy: 0.8409
# Epoch 175: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4302 - accuracy: 0.8400 - val_loss: 0.2150 - val_accuracy: 0.9686
# Epoch 176/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4073 - accuracy: 0.8419
# Epoch 176: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4173 - accuracy: 0.8361 - val_loss: 0.2138 - val_accuracy: 0.9677
# Epoch 177/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4148 - accuracy: 0.8396
# Epoch 177: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4259 - accuracy: 0.8370 - val_loss: 0.2240 - val_accuracy: 0.9659
# Epoch 178/1000
# 17/27 [=================>............] - ETA: 0s - loss: 0.4492 - accuracy: 0.8286
# Epoch 178: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4459 - accuracy: 0.8280 - val_loss: 0.2253 - val_accuracy: 0.9659
# Epoch 179/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4206 - accuracy: 0.8438
# Epoch 179: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4262 - accuracy: 0.8406 - val_loss: 0.2186 - val_accuracy: 0.9739
# Epoch 180/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4272 - accuracy: 0.8379
# Epoch 180: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4207 - accuracy: 0.8418 - val_loss: 0.2185 - val_accuracy: 0.9730
# Epoch 181/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4321 - accuracy: 0.8352
# Epoch 181: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4228 - accuracy: 0.8385 - val_loss: 0.2165 - val_accuracy: 0.9695
# Epoch 182/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4215 - accuracy: 0.8425
# Epoch 182: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4232 - accuracy: 0.8430 - val_loss: 0.2166 - val_accuracy: 0.9721
# Epoch 183/1000
# 21/27 [======================>.......] - ETA: 0s - loss: 0.4243 - accuracy: 0.8464
# Epoch 183: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4231 - accuracy: 0.8442 - val_loss: 0.2183 - val_accuracy: 0.9704
# Epoch 184/1000
# 18/27 [===================>..........] - ETA: 0s - loss: 0.4091 - accuracy: 0.8498
# Epoch 184: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4078 - accuracy: 0.8487 - val_loss: 0.2148 - val_accuracy: 0.9712
# Epoch 185/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4415 - accuracy: 0.8281
# Epoch 185: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4465 - accuracy: 0.8268 - val_loss: 0.2178 - val_accuracy: 0.9712
# Epoch 186/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4216 - accuracy: 0.8421
# Epoch 186: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 11ms/step - loss: 0.4178 - accuracy: 0.8385 - val_loss: 0.2222 - val_accuracy: 0.9712
# Epoch 187/1000
# 12/27 [============>.................] - ETA: 0s - loss: 0.4306 - accuracy: 0.8340
# Epoch 187: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4320 - accuracy: 0.8370 - val_loss: 0.2207 - val_accuracy: 0.9730
# Epoch 188/1000
# 20/27 [=====================>........] - ETA: 0s - loss: 0.4290 - accuracy: 0.8402
# Epoch 188: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4377 - accuracy: 0.8382 - val_loss: 0.2212 - val_accuracy: 0.9704
# Epoch 189/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4090 - accuracy: 0.8446
# Epoch 189: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4130 - accuracy: 0.8409 - val_loss: 0.2194 - val_accuracy: 0.9704
# Epoch 190/1000
# 19/27 [====================>.........] - ETA: 0s - loss: 0.4394 - accuracy: 0.8273
# Epoch 190: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4251 - accuracy: 0.8391 - val_loss: 0.2206 - val_accuracy: 0.9712
# Epoch 190: early stopping

# %%
# モデル評価
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2206 - accuracy: 0.9712

# %%
# 保存したモデルのロード
if USE_PRUNING:
    import tensorflow_model_optimization as tfmot
    with tfmot.sparsity.keras.prune_scope():
        model = tf.keras.models.load_model(model_save_path)
else:
    model = tf.keras.models.load_model(model_save_path)

# %%
# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 [==============================] - 0s 90ms/step
# [0.8855305  0.10164995 0.01281962]
# 0

# %% [markdown]
# # 混同行列

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 35/35 [==============================] - 0s 1ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       410
#            1       0.97      0.96      0.97       385
#            2       0.94      0.98      0.96       318
#
#     accuracy                           0.97      1113
#    macro avg       0.97      0.97      0.97      1113
# weighted avg       0.97      0.97      0.97      1113

# %% [markdown]
# # Tensorflow-Lite用のモデルへ変換

# %%
# Save model without optimizer for conversion
model.save(model_save_path, include_optimizer=False)
print(f"Saved model to {model_save_path}")
# Out:
# Saved model to model/keypoint_classifier/keypoint_classifier.hdf5

# %%
# Representative dataset generator for INT8 quantization
def representative_dataset_gen():
    """Generate representative dataset for INT8 quantization."""
    for i in range(min(100, len(X_train))):
        yield [X_train[i:i+1].astype(np.float32)]

# %%
import subprocess
import os

exported_models = []
base_path = "model/keypoint_classifier/keypoint_classifier"

print("=" * 60)
print("Starting Model Export Process")
print("=" * 60)

# 1. Dynamic Range Quantization (Default)
if EXPORT_DYNAMIC:
    print("\n[1/5] Exporting Dynamic Range Quantization...")
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite_model = converter.convert()
    
    save_path = f"{base_path}.tflite"
    with open(save_path, "wb") as f:
        f.write(tflite_model)
    exported_models.append(save_path)
    print(f"  ✓ Saved: {save_path} ({len(tflite_model)} bytes)")

# 2. INT8 Full Quantization
if EXPORT_INT8_FULL:
    print("\n[2/5] Exporting INT8 Full Quantization...")
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.representative_dataset = representative_dataset_gen
    converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
    converter.inference_input_type = tf.uint8
    converter.inference_output_type = tf.uint8
    tflite_model = converter.convert()
    
    save_path = f"{base_path}_int8.tflite"
    with open(save_path, "wb") as f:
        f.write(tflite_model)
    exported_models.append(save_path)
    print(f"  ✓ Saved: {save_path} ({len(tflite_model)} bytes)")
    
    # Try Edge TPU compilation
    if COMPILE_EDGE_TPU:
        print("    Attempting Edge TPU compilation...")
        try:
            result = subprocess.run(
                ["edgetpu_compiler", save_path, "-o", "model/keypoint_classifier"],
                capture_output=True,
                text=True,
                timeout=30
            )
            if result.returncode == 0:
                edgetpu_path = f"{base_path}_int8_edgetpu.tflite"
                if os.path.exists(edgetpu_path):
                    exported_models.append(edgetpu_path)
                    print(f"    ✓ Edge TPU model: {edgetpu_path}")
            else:
                print(f"    ⚠ Edge TPU compilation failed: {result.stderr}")
        except FileNotFoundError:
            print("    ⚠ edgetpu_compiler not found. Install from: https://coral.ai/docs/edgetpu/compiler/")
        except Exception as e:
            print(f"    ⚠ Edge TPU compilation error: {e}")

# 3. FP16 Quantization
if EXPORT_FP16:
    print("\n[3/5] Exporting FP16 Quantization...")
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.target_spec.supported_types = [tf.float16]
    tflite_model = converter.convert()
    
    save_path = f"{base_path}_fp16.tflite"
    with open(save_path, "wb") as f:
        f.write(tflite_model)
    exported_models.append(save_path)
    print(f"  ✓ Saved: {save_path} ({len(tflite_model)} bytes)")

# 4. INT8 with Pruning
if EXPORT_INT8_PRUNED:
    if USE_PRUNING:
        print("\n[4/5] Exporting INT8 with Pruning...")
        # Strip pruning wrappers
        import tensorflow_model_optimization as tfmot
        model_for_export = tfmot.sparsity.keras.strip_pruning(model)
        
        converter = tf.lite.TFLiteConverter.from_keras_model(model_for_export)
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        converter.representative_dataset = representative_dataset_gen
        converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
        converter.inference_input_type = tf.uint8
        converter.inference_output_type = tf.uint8
        tflite_model = converter.convert()
        
        save_path = f"{base_path}_int8_pruned.tflite"
        with open(save_path, "wb") as f:
            f.write(tflite_model)
        exported_models.append(save_path)
        print(f"  ✓ Saved: {save_path} ({len(tflite_model)} bytes)")
        
        # Try Edge TPU compilation
        if COMPILE_EDGE_TPU:
            print("    Attempting Edge TPU compilation...")
            try:
                result = subprocess.run(
                    ["edgetpu_compiler", save_path, "-o", "model/keypoint_classifier"],
                    capture_output=True,
                    text=True,
                    timeout=30
                )
                if result.returncode == 0:
                    edgetpu_path = f"{base_path}_int8_pruned_edgetpu.tflite"
                    if os.path.exists(edgetpu_path):
                        exported_models.append(edgetpu_path)
                        print(f"    ✓ Edge TPU model: {edgetpu_path}")
                else:
                    print(f"    ⚠ Edge TPU compilation failed: {result.stderr}")
            except FileNotFoundError:
                print("    ⚠ edgetpu_compiler not found")
            except Exception as e:
                print(f"    ⚠ Edge TPU compilation error: {e}")
    else:
        print("\n[4/5] INT8 with Pruning requires training with pruning enabled.")
        print("  ℹ Set EXPORT_INT8_PRUNED=True and re-run training.")

# 5. FP16 with Pruning
if EXPORT_FP16_PRUNED:
    if USE_PRUNING:
        print("\n[5/5] Exporting FP16 with Pruning...")
        # Strip pruning wrappers
        import tensorflow_model_optimization as tfmot
        model_for_export = tfmot.sparsity.keras.strip_pruning(model)
        
        converter = tf.lite.TFLiteConverter.from_keras_model(model_for_export)
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        converter.target_spec.supported_types = [tf.float16]
        tflite_model = converter.convert()
        
        save_path = f"{base_path}_fp16_pruned.tflite"
        with open(save_path, "wb") as f:
            f.write(tflite_model)
        exported_models.append(save_path)
        print(f"  ✓ Saved: {save_path} ({len(tflite_model)} bytes)")
    else:
        print("\n[5/5] FP16 with Pruning requires training with pruning enabled.")
        print("  ℹ Set EXPORT_FP16_PRUNED=True and re-run training.")

if EXPORT_FP16_PRUNED:
    print("\n[5/5] FP16 with Pruning requires retraining with pruning enabled.")
    print("  ℹ Set up pruning before training and re-run this notebook.")

print("\n" + "=" * 60)
print(f"Export Complete! Generated {len(exported_models)} model(s):")
print("=" * 60)
for model_path in exported_models:
    size_kb = os.path.getsize(model_path) / 1024
    print(f"  • {os.path.basename(model_path)}: {size_kb:.2f} KB")
# Out:
# ============================================================
# Starting Model Export Process
# ============================================================
#
# [4/5] Exporting INT8 with Pruning...
# INFO:tensorflow:Assets written to: /tmp/tmpnn7oq7xu/assets
# /home/mat/Documents/iot/hand-gesture-recognition-mediapipe/.env/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# 2026-01-07 15:54:25.035938: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2026-01-07 15:54:25.035959: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2026-01-07 15:54:25.036368: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /tmp/tmpnn7oq7xu
# 2026-01-07 15:54:25.037028: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2026-01-07 15:54:25.037043: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /tmp/tmpnn7oq7xu
# 2026-01-07 15:54:25.039568: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2026-01-07 15:54:25.040256: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
# 2026-01-07 15:54:25.054541: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: /tmp/tmpnn7oq7xu
# 2026-01-07 15:54:25.058897: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 22529 microseconds.
# 2026-01-07 15:54:25.071173: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# fully_quantize: 0, inference_type: 6, input_inference_type: UINT8, output_inference_type: UINT8
#   ✓ Saved: model/keypoint_classifier/keypoint_classifier_int8_pruned.tflite (4056 bytes)
#     Attempting Edge TPU compilation...
#     ✓ Edge TPU model: model/keypoint_classifier/keypoint_classifier_int8_pruned_edgetpu.tflite
#
# [5/5] Exporting FP16 with Pruning...
# INFO:tensorflow:Assets written to: /tmp/tmpxttty9_l/assets
# INFO:tensorflow:Assets written to: /tmp/tmpxttty9_l/assets
#   ✓ Saved: model/keypoint_classifier/keypoint_classifier_fp16_pruned.tflite (5244 bytes)
#
# [5/5] FP16 with Pruning requires retraining with pruning enabled.
#   ℹ Set up pruning before training and re-run this notebook.
#
# ============================================================
# Export Complete! Generated 3 model(s):
# ============================================================
#   • keypoint_classifier_int8_pruned.tflite: 3.96 KB
#   • keypoint_classifier_int8_pruned_edgetpu.tflite: 44.59 KB
#   • keypoint_classifier_fp16_pruned.tflite: 5.12 KB
# 2026-01-07 15:54:25.904944: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2026-01-07 15:54:25.904973: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2026-01-07 15:54:25.905083: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /tmp/tmpxttty9_l
# 2026-01-07 15:54:25.905732: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2026-01-07 15:54:25.905744: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /tmp/tmpxttty9_l
# 2026-01-07 15:54:25.908683: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
# 2026-01-07 15:54:25.919631: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: /tmp/tmpxttty9_l
# 2026-01-07 15:54:25.923422: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 18339 microseconds.
